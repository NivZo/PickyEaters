# %%
import random
import time
from math import sqrt
from functools import lru_cache
from collections import deque, defaultdict
from heapq import heappush, heappop

class Cell:
    def __init__(self, x, y):
        self.x, self.y, self.ent = x, y, None
    def empty(self): return self.ent is None

class Entity:
    def __init__(self, color): self.color = color

class Eater(Entity): pass

class Food(Entity):
    def __init__(self, color, is_last=False):
        super().__init__(color)
        self.is_last = is_last

class Grid:
    DIRS = [(0,1), (0,-1), (1,0), (-1,0)]
    COLOR_MAP = {
        'Food': {'White': 0, 'Green': 1, 'Blue': 2, 'Red': 3, 'Yellow': 4, 'Purple': 5, 'Pink': 6, 'Brown': 7},
        'Eater': {'Green': 0, 'Blue': 1, 'Red': 2, 'Yellow': 3, 'Purple': 4, 'Pink': 5, 'Brown': 6}
    }

    def __init__(self, rows, cols):
        self.rows, self.cols = rows, cols
        self.grid = [[Cell(x, y) for y in range(cols)] for x in range(rows)]
        self.moves = []
        self.min_separation = 2
        self._distance_cache = {}
        self.solution_paths = {}
        self.difficulty_score = 0

    def place(self, ent, x, y):
        self.grid[x][y].ent = ent

    def clear(self):
        for row in self.grid:
            for cell in row: cell.ent = None
        self.moves = []
        self._distance_cache = {}
        self.solution_paths = {}

    @lru_cache(maxsize=1024)
    def _manhattan_distance(self, pos1, pos2):
        return abs(pos1[0] - pos2[0]) + abs(pos1[1] - pos2[1])

    def analyze_board_complexity(self):
        self.difficulty_score = 0
        colors_present = self._get_colors_present()
        if not colors_present: return 0
        
        # Factor 1: Multiple solution paths
        self._calculate_solution_paths()
        path_scores = []
        for color in colors_present:
            paths = len(self.solution_paths.get(color, []))
            path_scores.append(min(paths, 5) * 20)  # Cap at 5 paths per color
        
        # Factor 2: Color interaction complexity
        blocking_score = self._calculate_blocking_complexity()
        
        # Factor 3: Decision points (junctions)
        junction_score = self._calculate_junction_complexity()
        
        # Factor 4: Path interleaving
        interleaving_score = self._calculate_path_interleaving()
        
        # Factor 5: Deceptive paths (paths that look correct but aren't)
        deceptive_score = self._calculate_deceptive_paths()
        
        self.difficulty_score = (sum(path_scores) / len(path_scores) if path_scores else 0) + \
                               blocking_score + junction_score + interleaving_score + deceptive_score
        
        return self.difficulty_score

    def _get_colors_present(self):
        colors = set()
        for row in self.grid:
            for cell in row:
                if isinstance(cell.ent, Eater):
                    colors.add(cell.ent.color)
        return colors

    def _calculate_solution_paths(self):
        self.solution_paths = {}
        for x in range(self.rows):
            for y in range(self.cols):
                if isinstance(self.grid[x][y].ent, Eater):
                    color = self.grid[x][y].ent.color
                    paths = self._find_all_valid_paths(x, y, color)
                    self.solution_paths[color] = paths
        return self.solution_paths

    def _find_all_valid_paths(self, eater_x, eater_y, color, max_paths=10):
        # Find the last food item of this color
        last_food = None
        for x in range(self.rows):
            for y in range(self.cols):
                if (isinstance(self.grid[x][y].ent, Food) and 
                    self.grid[x][y].ent.color == color and 
                    self.grid[x][y].ent.is_last):
                    last_food = (x, y)
                    break
            if last_food: break
        
        if not last_food: return []
        
        # Find all food of this color
        color_food = []
        for x in range(self.rows):
            for y in range(self.cols):
                if (isinstance(self.grid[x][y].ent, Food) and 
                    self.grid[x][y].ent.color == color):
                    color_food.append((x, y))
        
        paths = []
        queue = [(last_food, [last_food], set([last_food]))]
        while queue and len(paths) < max_paths:
            (curr_x, curr_y), path, visited = queue.pop(0)
            
            if (curr_x, curr_y) == (eater_x, eater_y) and set(color_food).issubset(visited):
                paths.append(path)
                continue
                
            for dx, dy in self.DIRS:
                nx, ny = curr_x + dx, curr_y + dy
                while self.in_bounds(nx, ny) and self._can_move_through(nx, ny, color):
                    if (nx, ny) not in visited:
                        new_path = path + [(nx, ny)]
                        new_visited = visited.copy()
                        new_visited.add((nx, ny))
                        queue.append(((nx, ny), new_path, new_visited))
                    nx, ny = nx + dx, ny + dy
                
        return paths

    def _can_move_through(self, x, y, color):
        cell = self.grid[x][y]
        if cell.empty(): 
            return True
        if isinstance(cell.ent, Food) and (cell.ent.color == color or cell.ent.color == 'White'):
            return True
        if isinstance(cell.ent, Eater) and cell.ent.color == color:
            return True
        return False

    def _calculate_blocking_complexity(self):
        colors = self._get_colors_present()
        if len(colors) <= 1: return 0
        
        blocking_pairs = 0
        for c1 in colors:
            for c2 in colors:
                if c1 != c2:
                    if self._colors_block_each_other(c1, c2):
                        blocking_pairs += 1
        
        return min(blocking_pairs * 25, 100)  # Cap at 100

    def _colors_block_each_other(self, color1, color2):
        # Check if food/eater of color1 blocks paths of color2
        for x in range(self.rows):
            for y in range(self.cols):
                if isinstance(self.grid[x][y].ent, (Food, Eater)) and self.grid[x][y].ent.color == color1:
                    if self._is_blocking_position(x, y, color2):
                        return True
        return False

    def _is_blocking_position(self, x, y, color):
        # Is this position blocking a path for the given color?
        paths = self.solution_paths.get(color, [])
        for path in paths:
            for px, py in path:
                if (px, py) == (x, y):
                    # Check if there's an alternative path that doesn't include this position
                    if not any(all((px, py) != pos for pos in alt_path) for alt_path in paths):
                        return True
        return False

    def _calculate_junction_complexity(self):
        junctions = []
        for x in range(self.rows):
            for y in range(self.cols):
                if self._is_junction(x, y):
                    junctions.append((x, y))
        
        return min(len(junctions) * 10, 100)

    def _is_junction(self, x, y):
        # A junction is a position where multiple paths diverge
        neighboring_empty = 0
        for dx, dy in self.DIRS:
            nx, ny = x + dx, y + dy
            if self.in_bounds(nx, ny) and self.grid[nx][ny].empty():
                neighboring_empty += 1
        return neighboring_empty > 2

    def _calculate_path_interleaving(self):
        colors = self._get_colors_present()
        if len(colors) <= 1: return 0
        
        interleaving_score = 0
        color_positions = {}
        
        for color in colors:
            positions = []
            for x in range(self.rows):
                for y in range(self.cols):
                    if isinstance(self.grid[x][y].ent, (Food, Eater)) and self.grid[x][y].ent.color == color:
                        positions.append((x, y))
            color_positions[color] = positions
        
        for c1, pos1 in color_positions.items():
            for c2, pos2 in color_positions.items():
                if c1 != c2:
                    # Calculate how interleaved the positions are
                    interleaving = 0
                    for p1 in pos1:
                        near_other = any(self._manhattan_distance(p1, p2) <= 2 for p2 in pos2)
                        if near_other:
                            interleaving += 1
                    
                    interleaving_score += (interleaving / max(len(pos1), 1)) * 20
        
        return min(interleaving_score, 100)

    def _calculate_deceptive_paths(self):
        # Deceptive paths look correct but lead to dead ends
        deceptive_score = 0
        for color, paths in self.solution_paths.items():
            if not paths: continue
            
            valid_path_positions = set()
            for path in paths:
                for pos in path:
                    valid_path_positions.add(pos)
            
            # Find dead end paths
            dead_ends = 0
            for x in range(self.rows):
                for y in range(self.cols):
                    if self.grid[x][y].empty() or (isinstance(self.grid[x][y].ent, Food) and 
                                                  self.grid[x][y].ent.color in (color, 'White')):
                        if (x, y) not in valid_path_positions and self._leads_to_dead_end(x, y, color):
                            dead_ends += 1
            
            deceptive_score += min(dead_ends * 15, 100)
        
        return min(deceptive_score, 100)

    def _leads_to_dead_end(self, x, y, color):
        # Check if this position leads to a dead end for the given color
        visited = set([(x, y)])
        queue = [(x, y)]
        found_exit = False
        
        while queue and not found_exit:
            curr_x, curr_y = queue.pop(0)
            
            for dx, dy in self.DIRS:
                nx, ny = curr_x + dx, curr_y + dy
                while self.in_bounds(nx, ny) and self._can_move_through(nx, ny, color):
                    if (nx, ny) not in visited:
                        visited.add((nx, ny))
                        queue.append((nx, ny))
                        
                        # Check if this is a valid part of a solution path
                        if any((nx, ny) in path for path in self.solution_paths.get(color, [])):
                            found_exit = True
                            break
                    
                    nx, ny = nx + dx, ny + dy
                
                if found_exit: break
                
        return not found_exit and len(visited) > 3  # Only count substantial dead ends

    def gen_puzzle(self, eaters, min_food, target_difficulty=None):
        best_board = None
        best_score_diff = float('inf')
        attempts = 0
        max_attempts = 20  # Limit attempts for performance
        
        while attempts < max_attempts:
            self.clear()
            eater_pos = []
            
            # Place eaters randomly
            colors = [c for c, n in eaters.items() for _ in range(n)]
            random.shuffle(colors)
            for color in colors:
                pos = self.get_empty()
                if not pos: break
                x, y = pos
                e = Eater(color)
                self.place(e, x, y)
                eater_pos.append({'e': e, 'x': x, 'y': y, 'count': 0})

            # Generate food paths
            active_eaters = eater_pos.copy()
            while active_eaters:
                moved_any = False
                for einfo in active_eaters[:]:
                    if einfo['count'] >= min_food:
                        active_eaters.remove(einfo)
                        continue
                    if self.move_eater(einfo):
                        moved_any = True
                    else:
                        active_eaters.remove(einfo)
                if not moved_any: break

            # Fill remaining spaces strategically to create challenging paths
            self._strategic_fill(eater_pos)
            
            # Calculate board difficulty
            difficulty = self.analyze_board_complexity()
            
            # If targeting a specific difficulty
            if target_difficulty is not None:
                score_diff = abs(difficulty - target_difficulty)
                if score_diff < best_score_diff:
                    best_score_diff = score_diff
                    best_board = self._clone_board()
                    
                    # If we're close enough to target, stop early
                    if score_diff < 50:
                        break
            elif best_board is None or difficulty > self.difficulty_score:
                best_board = self._clone_board()
            
            attempts += 1
        
        # Restore best board
        if best_board:
            self._restore_board(best_board)
        
        return self.difficulty_score

    def _clone_board(self):
        # Save current board state
        board_state = []
        for x in range(self.rows):
            row = []
            for y in range(self.cols):
                cell = self.grid[x][y]
                if cell.empty():
                    row.append(None)
                elif isinstance(cell.ent, Eater):
                    row.append(('Eater', cell.ent.color))
                elif isinstance(cell.ent, Food):
                    row.append(('Food', cell.ent.color, cell.ent.is_last))
            board_state.append(row)
        return {
            'board': board_state,
            'moves': self.moves.copy(),
            'difficulty': self.difficulty_score
        }

    def _restore_board(self, board_data):
        self.clear()
        for x in range(self.rows):
            for y in range(self.cols):
                item = board_data['board'][x][y]
                if item:
                    if item[0] == 'Eater':
                        self.place(Eater(item[1]), x, y)
                    elif item[0] == 'Food':
                        self.place(Food(item[1], is_last=item[2]), x, y)
        self.moves = board_data['moves'].copy()
        self.difficulty_score = board_data['difficulty']

    def _strategic_fill(self, eater_pos):
        # Strategically fill remaining spaces to create challenging paths
        remaining_spaces = self.count_empty()
        if remaining_spaces == 0: return
        
        eater_colors = {e['e'].color for e in eater_pos}
        if not eater_colors: return
        
        # Create some strategic food placements to increase complexity
        filled = 0
        color_cycle = list(eater_colors)
        random.shuffle(color_cycle)
        color_index = 0
        
        while filled < remaining_spaces and filled < len(color_cycle) * 3:  # Limit strategic placements
            color = color_cycle[color_index % len(color_cycle)]
            color_index += 1
            
            # Find a strategic position for this color
            strategic_pos = self._find_strategic_position(color)
            if strategic_pos:
                x, y = strategic_pos
                self.place(Food(color), x, y)
                filled += 1
        
        # Fill remaining spaces with random food
        empty_cells = [(x, y) for x in range(self.rows) for y in range(self.cols) 
                      if self.grid[x][y].empty()]
        random.shuffle(empty_cells)
        
        for x, y in empty_cells:
            color = random.choice(list(eater_colors))
            self.place(Food(color), x, y)

    def _find_strategic_position(self, color):
        # Find a position that would create interesting paths
        candidates = []
        
        # Look for positions that create junctions
        for x in range(self.rows):
            for y in range(self.cols):
                if not self.grid[x][y].empty(): continue
                
                # Check if this would create a junction
                neighboring_empty = sum(1 for dx, dy in self.DIRS 
                                       if self.in_bounds(x+dx, y+dy) and self.grid[x+dx][y+dy].empty())
                
                if neighboring_empty >= 2:
                    # Check if near other colors (increases interleaving)
                    near_other_colors = False
                    for dx, dy in self.DIRS:
                        nx, ny = x+dx, y+dy
                        if self.in_bounds(nx, ny) and not self.grid[nx][ny].empty():
                            ent = self.grid[nx][ny].ent
                            if isinstance(ent, (Food, Eater)) and ent.color != color:
                                near_other_colors = True
                                break
                    
                    score = neighboring_empty * 2
                    if near_other_colors:
                        score += 4
                    
                    candidates.append((score, x, y))
        
        if candidates:
            candidates.sort(reverse=True)  # Higher scores first
            return candidates[0][1], candidates[0][2]
        
        # If no good candidates, find any empty space
        empty = self.get_empty()
        return empty

    def move_eater(self, einfo):
        random.shuffle(self.DIRS)
        
        for dx, dy in self.DIRS:
            x, y = einfo['x'], einfo['y']
            new_x, new_y = self.get_max_pos(x, y, dx, dy)
            
            if new_x is None or (new_x == x and new_y == y):
                continue
            
            # Place food where eater was
            is_first_food = einfo['count'] == 0
            self.grid[x][y].ent = None
            self.place(einfo['e'], new_x, new_y)
            self.place(Food(einfo['e'].color, is_last=is_first_food), x, y)
            einfo['count'] += abs(new_x - x) + abs(new_y - y)
            
            self.moves.append({
                'eater_color': einfo['e'].color,
                'start': (new_x, new_y),
                'end': (x, y),
                'food_color': einfo['e'].color,
                'dist': abs(new_x - x) + abs(new_y - y)
            })
            
            einfo['x'], einfo['y'] = new_x, new_y
            return True
            
        return False

    def get_max_pos(self, x, y, dx, dy):
        nx, ny = x, y
        while self.in_bounds(nx + dx, ny + dy) and self.grid[nx + dx][ny + dy].empty():
            nx += dx
            ny += dy
        return (nx, ny) if (nx, ny) != (x, y) else (None, None)

    def get_empty(self):
        empty = [(x,y) for x in range(self.rows) for y in range(self.cols) 
                if self.grid[x][y].empty()]
        return random.choice(empty) if empty else None

    def in_bounds(self, x, y):
        return 0 <= x < self.rows and 0 <= y < self.cols

    def count_empty(self):
        return sum(1 for row in self.grid for cell in row if cell.empty())

    def to_scene(self, level_id):
        width, height = 1440, 2560
        step = max(180, width // self.cols - 24)
        
        start_x = width/2 - step*self.cols/2 + step*0.5
        start_y = height/2 - step*self.rows/2 + step*0.5 - 40

        scene = f"""[gd_scene load_steps=4 format=3 uid="{level_id}"]

[ext_resource type="Script" path="res://Levels/Level.cs" id="lvlid"]
[ext_resource type="PackedScene" uid="uid://byatslmwbvorg" path="res://Entities/Food/Food.tscn" id="foodid"]
[ext_resource type="PackedScene" uid="uid://dd570jgysudow" path="res://Entities/Eater/Eater.tscn" id="eaterid"]

[node name="Level" type="Node"]
script = ExtResource("lvlid")
{self.solution_metadata()}

[node name="Food" type="Node" parent="."]

[node name="Eaters" type="Node" parent="."]
"""
        for x in range(self.rows):
            for y in range(self.cols):
                cell = self.grid[x][y]
                pos_x = start_x + y*step
                pos_y = start_y + x*step
                
                if isinstance(cell.ent, Food):
                    scene += f"""
[node name="Food{x}_{y}" parent="Food" instance=ExtResource("foodid")]
position = Vector2({pos_x}, {pos_y})
BoardStatePositionId = Vector2i({x}, {y})
FoodType = {self.COLOR_MAP['Food'][cell.ent.color]}
IsLast = {"true" if cell.ent.is_last else "false"}
"""
                elif isinstance(cell.ent, Eater):
                    scene += f"""
[node name="Eater{x}_{y}" parent="Eaters" instance=ExtResource("eaterid")]
position = Vector2({pos_x}, {pos_y})
EaterType = {self.COLOR_MAP['Eater'][cell.ent.color]}
BoardStatePositionId = Vector2i({x}, {y})
ValidFoodTypes = [0, {self.COLOR_MAP['Food'][cell.ent.color]}]
"""
        return scene

    def solution_metadata(self):
        metadata = "metadata/solution = PackedVector2Array("
        for move in self.moves:
                metadata += f"{move['start'][0]}, {move['start'][1]}, {move['end'][0]}, {move['end'][1]}, "
        metadata = metadata[:-2] + ")" if self.moves else metadata + ")"
        return metadata

def gen_boards(num_select, total_gen, rows, cols, eaters, min_food, difficulty_range=None):
    boards = []
    attempts = 0
    max_tries = total_gen * 5
    
    # Define difficulty ranges (low, medium, high)
    difficulty_targets = None
    if difficulty_range:
        if difficulty_range == "easy":
            difficulty_targets = [100, 200]
        elif difficulty_range == "medium":
            difficulty_targets = [300, 400]
        elif difficulty_range == "hard":
            difficulty_targets = [500, 600]
    
    while len(boards) < total_gen and attempts < max_tries:
        g = Grid(rows, cols)
        target = None
        if difficulty_targets:
            target = random.randint(difficulty_targets[0], difficulty_targets[1])
        
        difficulty = g.gen_puzzle(eaters, min_food, target)
        
        empty_count = g.count_empty()
        if empty_count == 0:
            # All spaces filled, consider it a valid board
            boards.append({
                'board': g,
                'difficulty': difficulty
            })
            print(f"Generated board {len(boards)}/{total_gen} with difficulty {difficulty}")
        
        attempts += 1

    # Sort by difficulty (ascending or descending based on preference)
    boards.sort(key=lambda x: x['difficulty'], reverse=True)  # Higher difficulty first
    return boards[:num_select]

# %%
# Example usage
if __name__ == "__main__":
    # Configuration
    DIFFICULTY = {
        'tutorial': ({'Green': 1}, 3, 3, 2, 30, 1, 0),
        'very_easy': ({'Blue': 1, 'Green': 1}, 4, 4, 3, 30, 2, 0),
        'very_easy2': ({'Blue': 1, 'Green': 1}, 5, 4, 10, 30, 2, 1),
        'easy': ({'Blue': 1, 'Green': 1, 'Red': 1}, 5, 5, 15, 30, 3, 2),
        'easy2': ({'Blue': 1, 'Green': 1, 'Red': 1}, 6, 5, 15, 30, 3, 3),
        'medium': ({'Blue': 1, 'Green': 1, 'Red': 1, 'Yellow': 1}, 6, 6, 20, 20, 3, 4),
        'medium2': ({'Blue': 1, 'Green': 1, 'Red': 1, 'Yellow': 1}, 7, 6, 20, 20, 3, 4),
        'hard': ({'Blue': 1, 'Green': 1, 'Red': 1, 'Yellow': 1, 'Pink': 1}, 7, 7, 20, 20, 3, 5),
        'hard2': ({'Blue': 1, 'Green': 1, 'Red': 1, 'Yellow': 1, 'Pink': 1}, 8, 7, 20, 20, 4, 5),
        'veryhard': ({'Blue': 1, 'Green': 1, 'Red': 1, 'Yellow': 1, 'Pink': 1, 'Purple': 1}, 9, 7, 20, 20, 4, 6),
        'veryhard2': ({'Blue': 1, 'Green': 1, 'Red': 1, 'Yellow': 1, 'Pink': 1, 'Purple': 1}, 10, 7, 20, 20, 4, 6),
        'max': ({'Blue': 1, 'Green': 1, 'Red': 1, 'Yellow': 1, 'Pink': 1, 'Purple': 1, 'Brown': 1}, 11, 7, 20, 15, 4, 7),
        'max2': ({'Blue': 1, 'Green': 1, 'Red': 1, 'Yellow': 1, 'Pink': 1, 'Purple': 1, 'Brown': 1}, 11, 7, 20, 10, 5, 7)
    }

    lvlid = 1
    ts = time.time()
    print(f"[{ts}] Starting")
    for diff, (eaters, rows, cols, num_select, white_pct, min_food, minimum_qualified_colors) in DIFFICULTY.items():
        new_boards = gen_boards(num_select, 5000, rows, cols, eaters, min_food, "hard")
        ts = time.time()
        for board in new_boards:
            with open(f"../Levels/NewLevel{lvlid}.tscn", "w") as f:
                f.write(board["board"].to_scene(lvlid))
            lvlid += 1
# Out:
# [1741025095.5715697] Starting
# Generated board 1/5000 with difficulty 100.0
# Generated board 2/5000 with difficulty 100.0
# Generated board 3/5000 with difficulty 100.0
# Generated board 4/5000 with difficulty 100.0
# Generated board 5/5000 with difficulty 100.0
# Generated board 6/5000 with difficulty 100.0
# Generated board 7/5000 with difficulty 100.0
# Generated board 8/5000 with difficulty 100.0
# Generated board 9/5000 with difficulty 100.0
# Generated board 10/5000 with difficulty 100.0
# Generated board 11/5000 with difficulty 100.0
# Generated board 12/5000 with difficulty 100.0
# Generated board 13/5000 with difficulty 100.0
# Generated board 14/5000 with difficulty 100.0
# Generated board 15/5000 with difficulty 100.0
# Generated board 16/5000 with difficulty 100.0
# Generated board 17/5000 with difficulty 100.0
# Generated board 18/5000 with difficulty 100.0
# Generated board 19/5000 with difficulty 100.0
# Generated board 20/5000 with difficulty 100.0
# Generated board 21/5000 with difficulty 100.0
# Generated board 22/5000 with difficulty 100.0
# Generated board 23/5000 with difficulty 100.0
# Generated board 24/5000 with difficulty 100.0
# Generated board 25/5000 with difficulty 100.0
# Generated board 26/5000 with difficulty 100.0
# Generated board 27/5000 with difficulty 100.0
# Generated board 28/5000 with difficulty 100.0
# Generated board 29/5000 with difficulty 100.0
# Generated board 30/5000 with difficulty 100.0
# Generated board 31/5000 with difficulty 100.0
# Generated board 32/5000 with difficulty 100.0
# Generated board 33/5000 with difficulty 100.0
# Generated board 34/5000 with difficulty 100.0
# Generated board 35/5000 with difficulty 100.0
# Generated board 36/5000 with difficulty 100.0
# Generated board 37/5000 with difficulty 100.0
# Generated board 38/5000 with difficulty 100.0
# Generated board 39/5000 with difficulty 100.0
# Generated board 40/5000 with difficulty 100.0
# Generated board 41/5000 with difficulty 100.0
# Generated board 42/5000 with difficulty 100.0
# Generated board 43/5000 with difficulty 100.0
# Generated board 44/5000 with difficulty 100.0
# Generated board 45/5000 with difficulty 100.0
# Generated board 46/5000 with difficulty 100.0
# Generated board 47/5000 with difficulty 100.0
# Generated board 48/5000 with difficulty 100.0
# Generated board 49/5000 with difficulty 100.0
# Generated board 50/5000 with difficulty 100.0
# Generated board 51/5000 with difficulty 100.0
# Generated board 52/5000 with difficulty 100.0
# Generated board 53/5000 with difficulty 100.0
# Generated board 54/5000 with difficulty 100.0
# Generated board 55/5000 with difficulty 100.0
# Generated board 56/5000 with difficulty 100.0
# Generated board 57/5000 with difficulty 100.0
# Generated board 58/5000 with difficulty 100.0
# Generated board 59/5000 with difficulty 100.0
# Generated board 60/5000 with difficulty 100.0
# Generated board 61/5000 with difficulty 100.0
# Generated board 62/5000 with difficulty 100.0
# Generated board 63/5000 with difficulty 100.0
# Generated board 64/5000 with difficulty 100.0
# Generated board 65/5000 with difficulty 100.0
# Generated board 66/5000 with difficulty 100.0
# Generated board 67/5000 with difficulty 100.0
# Generated board 68/5000 with difficulty 100.0
# Generated board 69/5000 with difficulty 100.0
# Generated board 70/5000 with difficulty 100.0
# Generated board 71/5000 with difficulty 100.0
# Generated board 72/5000 with difficulty 100.0
# Generated board 73/5000 with difficulty 100.0
# Generated board 74/5000 with difficulty 100.0
# Generated board 75/5000 with difficulty 100.0
# Generated board 76/5000 with difficulty 100.0
# Generated board 77/5000 with difficulty 100.0
# Generated board 78/5000 with difficulty 100.0
# Generated board 79/5000 with difficulty 100.0
# Generated board 80/5000 with difficulty 100.0
# Generated board 81/5000 with difficulty 100.0
# Generated board 82/5000 with difficulty 100.0
# Generated board 83/5000 with difficulty 100.0
# Generated board 84/5000 with difficulty 100.0
# Generated board 85/5000 with difficulty 100.0
# Generated board 86/5000 with difficulty 100.0
# Generated board 87/5000 with difficulty 100.0
# Generated board 88/5000 with difficulty 100.0
# Generated board 89/5000 with difficulty 100.0
# Generated board 90/5000 with difficulty 100.0
# Generated board 91/5000 with difficulty 100.0
# Generated board 92/5000 with difficulty 100.0
# Generated board 93/5000 with difficulty 100.0
# Generated board 94/5000 with difficulty 100.0
# Generated board 95/5000 with difficulty 100.0
# Generated board 96/5000 with difficulty 100.0
# Generated board 97/5000 with difficulty 100.0
# Generated board 98/5000 with difficulty 100.0
# Generated board 99/5000 with difficulty 100.0
# Generated board 100/5000 with difficulty 100.0
# Generated board 101/5000 with difficulty 100.0
# Generated board 102/5000 with difficulty 100.0
# Generated board 103/5000 with difficulty 100.0
# Generated board 104/5000 with difficulty 100.0
# Generated board 105/5000 with difficulty 100.0
# Generated board 106/5000 with difficulty 100.0
# Generated board 107/5000 with difficulty 100.0
# Generated board 108/5000 with difficulty 100.0
# Generated board 109/5000 with difficulty 100.0
# Generated board 110/5000 with difficulty 100.0
# Generated board 111/5000 with difficulty 100.0
# Generated board 112/5000 with difficulty 100.0
# Generated board 113/5000 with difficulty 100.0
# Generated board 114/5000 with difficulty 100.0
# Generated board 115/5000 with difficulty 100.0
# Generated board 116/5000 with difficulty 100.0
# Generated board 117/5000 with difficulty 100.0
# Generated board 118/5000 with difficulty 100.0
# Generated board 119/5000 with difficulty 100.0
# Generated board 120/5000 with difficulty 100.0
# Generated board 121/5000 with difficulty 100.0
# Generated board 122/5000 with difficulty 100.0
# Generated board 123/5000 with difficulty 100.0
# Generated board 124/5000 with difficulty 100.0
# Generated board 125/5000 with difficulty 100.0
# Generated board 126/5000 with difficulty 100.0
# Generated board 127/5000 with difficulty 100.0
# Generated board 128/5000 with difficulty 100.0
# Generated board 129/5000 with difficulty 100.0
# Generated board 130/5000 with difficulty 100.0
# Generated board 131/5000 with difficulty 100.0
# Generated board 132/5000 with difficulty 100.0
# Generated board 133/5000 with difficulty 100.0
# Generated board 134/5000 with difficulty 100.0
# Generated board 135/5000 with difficulty 100.0
# Generated board 136/5000 with difficulty 100.0
# Generated board 137/5000 with difficulty 100.0
# Generated board 138/5000 with difficulty 100.0
# Generated board 139/5000 with difficulty 100.0
# Generated board 140/5000 with difficulty 100.0
# Generated board 141/5000 with difficulty 100.0
# Generated board 142/5000 with difficulty 100.0
# Generated board 143/5000 with difficulty 100.0
# Generated board 144/5000 with difficulty 100.0
# Generated board 145/5000 with difficulty 100.0
# Generated board 146/5000 with difficulty 100.0
# Generated board 147/5000 with difficulty 100.0
# Generated board 148/5000 with difficulty 100.0
# Generated board 149/5000 with difficulty 100.0
# Generated board 150/5000 with difficulty 100.0
# Generated board 151/5000 with difficulty 100.0
# Generated board 152/5000 with difficulty 100.0
# Generated board 153/5000 with difficulty 100.0
# Generated board 154/5000 with difficulty 100.0
# Generated board 155/5000 with difficulty 100.0
# Generated board 156/5000 with difficulty 100.0
# Generated board 157/5000 with difficulty 100.0
# Generated board 158/5000 with difficulty 100.0
# Generated board 159/5000 with difficulty 100.0
# Generated board 160/5000 with difficulty 100.0
# Generated board 161/5000 with difficulty 100.0
# Generated board 162/5000 with difficulty 100.0
# Generated board 163/5000 with difficulty 100.0
# Generated board 164/5000 with difficulty 100.0
# Generated board 165/5000 with difficulty 100.0
# Generated board 166/5000 with difficulty 100.0
# Generated board 167/5000 with difficulty 100.0
# Generated board 168/5000 with difficulty 100.0
# Generated board 169/5000 with difficulty 100.0
# Generated board 170/5000 with difficulty 100.0
# Generated board 171/5000 with difficulty 100.0
# Generated board 172/5000 with difficulty 100.0
# Generated board 173/5000 with difficulty 100.0
# Generated board 174/5000 with difficulty 100.0
# Generated board 175/5000 with difficulty 100.0
# Generated board 176/5000 with difficulty 100.0
# Generated board 177/5000 with difficulty 100.0
# Generated board 178/5000 with difficulty 100.0
# Generated board 179/5000 with difficulty 100.0
# Generated board 180/5000 with difficulty 100.0
# Generated board 181/5000 with difficulty 100.0
# Generated board 182/5000 with difficulty 100.0
# Generated board 183/5000 with difficulty 100.0
# Generated board 184/5000 with difficulty 100.0
# Generated board 185/5000 with difficulty 100.0
# Generated board 186/5000 with difficulty 100.0
# Generated board 187/5000 with difficulty 100.0
# Generated board 188/5000 with difficulty 100.0
# Generated board 189/5000 with difficulty 100.0
# Generated board 190/5000 with difficulty 100.0
# Generated board 191/5000 with difficulty 100.0
# Generated board 192/5000 with difficulty 100.0
# Generated board 193/5000 with difficulty 100.0
# Generated board 194/5000 with difficulty 100.0
# Generated board 195/5000 with difficulty 100.0
# Generated board 196/5000 with difficulty 100.0
# Generated board 197/5000 with difficulty 100.0
# Generated board 198/5000 with difficulty 100.0
# Generated board 199/5000 with difficulty 100.0
# Generated board 200/5000 with difficulty 100.0
# Generated board 201/5000 with difficulty 100.0
# Generated board 202/5000 with difficulty 100.0
# Generated board 203/5000 with difficulty 100.0
# Generated board 204/5000 with difficulty 100.0
# Generated board 205/5000 with difficulty 100.0
# Generated board 206/5000 with difficulty 100.0
# Generated board 207/5000 with difficulty 100.0
# Generated board 208/5000 with difficulty 100.0
# Generated board 209/5000 with difficulty 100.0
# Generated board 210/5000 with difficulty 100.0
# Generated board 211/5000 with difficulty 100.0
# Generated board 212/5000 with difficulty 100.0
# Generated board 213/5000 with difficulty 100.0
# Generated board 214/5000 with difficulty 100.0
# Generated board 215/5000 with difficulty 100.0
# Generated board 216/5000 with difficulty 100.0
# Generated board 217/5000 with difficulty 100.0
# Generated board 218/5000 with difficulty 100.0
# Generated board 219/5000 with difficulty 100.0
# Generated board 220/5000 with difficulty 100.0
# Generated board 221/5000 with difficulty 100.0
# Generated board 222/5000 with difficulty 100.0
# Generated board 223/5000 with difficulty 100.0
# Generated board 224/5000 with difficulty 100.0
# Generated board 225/5000 with difficulty 100.0
# Generated board 226/5000 with difficulty 100.0
# Generated board 227/5000 with difficulty 100.0
# Generated board 228/5000 with difficulty 100.0
# Generated board 229/5000 with difficulty 100.0
# Generated board 230/5000 with difficulty 100.0
# Generated board 231/5000 with difficulty 100.0
# Generated board 232/5000 with difficulty 100.0
# Generated board 233/5000 with difficulty 100.0
# Generated board 234/5000 with difficulty 100.0
# Generated board 235/5000 with difficulty 100.0
# Generated board 236/5000 with difficulty 100.0
# Generated board 237/5000 with difficulty 100.0
# Generated board 238/5000 with difficulty 100.0
# Generated board 239/5000 with difficulty 100.0
# Generated board 240/5000 with difficulty 100.0
# Generated board 241/5000 with difficulty 100.0
# Generated board 242/5000 with difficulty 100.0
# Generated board 243/5000 with difficulty 100.0
# Generated board 244/5000 with difficulty 100.0
# Generated board 245/5000 with difficulty 100.0
# Generated board 246/5000 with difficulty 100.0
# Generated board 247/5000 with difficulty 100.0
# Generated board 248/5000 with difficulty 100.0
# Generated board 249/5000 with difficulty 100.0
# Generated board 250/5000 with difficulty 100.0
# Generated board 251/5000 with difficulty 100.0
# Generated board 252/5000 with difficulty 100.0
# Generated board 253/5000 with difficulty 100.0
# Generated board 254/5000 with difficulty 100.0
# Generated board 255/5000 with difficulty 100.0
# Generated board 256/5000 with difficulty 100.0
# Generated board 257/5000 with difficulty 100.0
# Generated board 258/5000 with difficulty 100.0
# Generated board 259/5000 with difficulty 100.0
# Generated board 260/5000 with difficulty 100.0
# Generated board 261/5000 with difficulty 100.0
# Generated board 262/5000 with difficulty 100.0
# Generated board 263/5000 with difficulty 100.0
# Generated board 264/5000 with difficulty 100.0
# Generated board 265/5000 with difficulty 100.0
# Generated board 266/5000 with difficulty 100.0
# Generated board 267/5000 with difficulty 100.0
# Generated board 268/5000 with difficulty 100.0
# Generated board 269/5000 with difficulty 100.0
# Generated board 270/5000 with difficulty 100.0
# Generated board 271/5000 with difficulty 100.0
# Generated board 272/5000 with difficulty 100.0
# Generated board 273/5000 with difficulty 100.0
# Generated board 274/5000 with difficulty 100.0
# Generated board 275/5000 with difficulty 100.0
# Generated board 276/5000 with difficulty 100.0
# Generated board 277/5000 with difficulty 100.0
# Generated board 278/5000 with difficulty 100.0
# Generated board 279/5000 with difficulty 100.0
# Generated board 280/5000 with difficulty 100.0
# Generated board 281/5000 with difficulty 100.0
# Generated board 282/5000 with difficulty 100.0
# Generated board 283/5000 with difficulty 100.0
# Generated board 284/5000 with difficulty 100.0
# Generated board 285/5000 with difficulty 100.0
# Generated board 286/5000 with difficulty 100.0
# Generated board 287/5000 with difficulty 100.0
# Generated board 288/5000 with difficulty 100.0
# Generated board 289/5000 with difficulty 100.0
# Generated board 290/5000 with difficulty 100.0
# Generated board 291/5000 with difficulty 100.0
# Generated board 292/5000 with difficulty 100.0
# Generated board 293/5000 with difficulty 100.0
# Generated board 294/5000 with difficulty 100.0
# Generated board 295/5000 with difficulty 100.0
# Generated board 296/5000 with difficulty 100.0
# Generated board 297/5000 with difficulty 100.0
# Generated board 298/5000 with difficulty 100.0
# Generated board 299/5000 with difficulty 100.0
# Generated board 300/5000 with difficulty 100.0
# Generated board 301/5000 with difficulty 100.0
# Generated board 302/5000 with difficulty 100.0
# Generated board 303/5000 with difficulty 100.0
# Generated board 304/5000 with difficulty 100.0
# Generated board 305/5000 with difficulty 100.0
# Generated board 306/5000 with difficulty 100.0
# Generated board 307/5000 with difficulty 100.0
# Generated board 308/5000 with difficulty 100.0
# Generated board 309/5000 with difficulty 100.0
# Generated board 310/5000 with difficulty 100.0
# Generated board 311/5000 with difficulty 100.0
# Generated board 312/5000 with difficulty 100.0
# Generated board 313/5000 with difficulty 100.0
# Generated board 314/5000 with difficulty 100.0
# Generated board 315/5000 with difficulty 100.0
# Generated board 316/5000 with difficulty 100.0
# Generated board 317/5000 with difficulty 100.0
# Generated board 318/5000 with difficulty 100.0
# Generated board 319/5000 with difficulty 100.0
# Generated board 320/5000 with difficulty 100.0
# Generated board 321/5000 with difficulty 100.0
# Generated board 322/5000 with difficulty 100.0
# Generated board 323/5000 with difficulty 100.0
# Generated board 324/5000 with difficulty 100.0
# Generated board 325/5000 with difficulty 100.0
# Generated board 326/5000 with difficulty 100.0
# Generated board 327/5000 with difficulty 100.0
# Generated board 328/5000 with difficulty 100.0
# Generated board 329/5000 with difficulty 100.0
# Generated board 330/5000 with difficulty 100.0
# Generated board 331/5000 with difficulty 100.0
# Generated board 332/5000 with difficulty 100.0
# Generated board 333/5000 with difficulty 100.0
# Generated board 334/5000 with difficulty 100.0
# Generated board 335/5000 with difficulty 100.0
# Generated board 336/5000 with difficulty 100.0
# Generated board 337/5000 with difficulty 100.0
# Generated board 338/5000 with difficulty 100.0
# Generated board 339/5000 with difficulty 100.0
# Generated board 340/5000 with difficulty 100.0
# Generated board 341/5000 with difficulty 100.0
# Generated board 342/5000 with difficulty 100.0
# Generated board 343/5000 with difficulty 100.0
# Generated board 344/5000 with difficulty 100.0
# Generated board 345/5000 with difficulty 100.0
# Generated board 346/5000 with difficulty 100.0
# Generated board 347/5000 with difficulty 100.0
# Generated board 348/5000 with difficulty 100.0
# Generated board 349/5000 with difficulty 100.0
# Generated board 350/5000 with difficulty 100.0
# Generated board 351/5000 with difficulty 100.0
# Generated board 352/5000 with difficulty 100.0
# Generated board 353/5000 with difficulty 100.0
# Generated board 354/5000 with difficulty 100.0
# Generated board 355/5000 with difficulty 100.0
# Generated board 356/5000 with difficulty 100.0
# Generated board 357/5000 with difficulty 100.0
# Generated board 358/5000 with difficulty 100.0
# Generated board 359/5000 with difficulty 100.0
# Generated board 360/5000 with difficulty 100.0
# Generated board 361/5000 with difficulty 100.0
# Generated board 362/5000 with difficulty 100.0
# Generated board 363/5000 with difficulty 100.0
# Generated board 364/5000 with difficulty 100.0
# Generated board 365/5000 with difficulty 100.0
# Generated board 366/5000 with difficulty 100.0
# Generated board 367/5000 with difficulty 100.0
# Generated board 368/5000 with difficulty 100.0
# Generated board 369/5000 with difficulty 100.0
# Generated board 370/5000 with difficulty 100.0
# Generated board 371/5000 with difficulty 100.0
# Generated board 372/5000 with difficulty 100.0
# Generated board 373/5000 with difficulty 100.0
# Generated board 374/5000 with difficulty 100.0
# Generated board 375/5000 with difficulty 100.0
# Generated board 376/5000 with difficulty 100.0
# Generated board 377/5000 with difficulty 100.0
# Generated board 378/5000 with difficulty 100.0
# Generated board 379/5000 with difficulty 100.0
# Generated board 380/5000 with difficulty 100.0
# Generated board 381/5000 with difficulty 100.0
# Generated board 382/5000 with difficulty 100.0
# Generated board 383/5000 with difficulty 100.0
# Generated board 384/5000 with difficulty 100.0
# Generated board 385/5000 with difficulty 100.0
# Generated board 386/5000 with difficulty 100.0
# Generated board 387/5000 with difficulty 100.0
# Generated board 388/5000 with difficulty 100.0
# Generated board 389/5000 with difficulty 100.0
# Generated board 390/5000 with difficulty 100.0
# Generated board 391/5000 with difficulty 100.0
# Generated board 392/5000 with difficulty 100.0
# Generated board 393/5000 with difficulty 100.0
# Generated board 394/5000 with difficulty 100.0
# Generated board 395/5000 with difficulty 100.0
# Generated board 396/5000 with difficulty 100.0
# Generated board 397/5000 with difficulty 100.0
# Generated board 398/5000 with difficulty 100.0
# Generated board 399/5000 with difficulty 100.0
# Generated board 400/5000 with difficulty 100.0
# Generated board 401/5000 with difficulty 100.0
# Generated board 402/5000 with difficulty 100.0
# Generated board 403/5000 with difficulty 100.0
# Generated board 404/5000 with difficulty 100.0
# Generated board 405/5000 with difficulty 100.0
# Generated board 406/5000 with difficulty 100.0
# Generated board 407/5000 with difficulty 100.0
# Generated board 408/5000 with difficulty 100.0
# Generated board 409/5000 with difficulty 100.0
# Generated board 410/5000 with difficulty 100.0
# Generated board 411/5000 with difficulty 100.0
# Generated board 412/5000 with difficulty 100.0
# Generated board 413/5000 with difficulty 100.0
# Generated board 414/5000 with difficulty 100.0
# Generated board 415/5000 with difficulty 100.0
# Generated board 416/5000 with difficulty 100.0
# Generated board 417/5000 with difficulty 100.0
# Generated board 418/5000 with difficulty 100.0
# Generated board 419/5000 with difficulty 100.0
# Generated board 420/5000 with difficulty 100.0
# Generated board 421/5000 with difficulty 100.0
# Generated board 422/5000 with difficulty 100.0
# Generated board 423/5000 with difficulty 100.0
# Generated board 424/5000 with difficulty 100.0
# Generated board 425/5000 with difficulty 100.0
# Generated board 426/5000 with difficulty 100.0
# Generated board 427/5000 with difficulty 100.0
# Generated board 428/5000 with difficulty 100.0
# Generated board 429/5000 with difficulty 100.0
# Generated board 430/5000 with difficulty 100.0
# Generated board 431/5000 with difficulty 100.0
# Generated board 432/5000 with difficulty 100.0
# Generated board 433/5000 with difficulty 100.0
# Generated board 434/5000 with difficulty 100.0
# Generated board 435/5000 with difficulty 100.0
# Generated board 436/5000 with difficulty 100.0
# Generated board 437/5000 with difficulty 100.0
# Generated board 438/5000 with difficulty 100.0
# Generated board 439/5000 with difficulty 100.0
# Generated board 440/5000 with difficulty 100.0
# Generated board 441/5000 with difficulty 100.0
# Generated board 442/5000 with difficulty 100.0
# Generated board 443/5000 with difficulty 100.0
# Generated board 444/5000 with difficulty 100.0
# Generated board 445/5000 with difficulty 100.0
# Generated board 446/5000 with difficulty 100.0
# Generated board 447/5000 with difficulty 100.0
# Generated board 448/5000 with difficulty 100.0
# Generated board 449/5000 with difficulty 100.0
# Generated board 450/5000 with difficulty 100.0
# Generated board 451/5000 with difficulty 100.0
# Generated board 452/5000 with difficulty 100.0
# Generated board 453/5000 with difficulty 100.0
# Generated board 454/5000 with difficulty 100.0
# Generated board 455/5000 with difficulty 100.0
# Generated board 456/5000 with difficulty 100.0
# Generated board 457/5000 with difficulty 100.0
# Generated board 458/5000 with difficulty 100.0
# Generated board 459/5000 with difficulty 100.0
# Generated board 460/5000 with difficulty 100.0
# Generated board 461/5000 with difficulty 100.0
# Generated board 462/5000 with difficulty 100.0
# Generated board 463/5000 with difficulty 100.0
# Generated board 464/5000 with difficulty 100.0
# Generated board 465/5000 with difficulty 100.0
# Generated board 466/5000 with difficulty 100.0
# Generated board 467/5000 with difficulty 100.0
# Generated board 468/5000 with difficulty 100.0
# Generated board 469/5000 with difficulty 100.0
# Generated board 470/5000 with difficulty 100.0
# Generated board 471/5000 with difficulty 100.0
# Generated board 472/5000 with difficulty 100.0
# Generated board 473/5000 with difficulty 100.0
# Generated board 474/5000 with difficulty 100.0
# Generated board 475/5000 with difficulty 100.0
# Generated board 476/5000 with difficulty 100.0
# Generated board 477/5000 with difficulty 100.0
# Generated board 478/5000 with difficulty 100.0
# Generated board 479/5000 with difficulty 100.0
# Generated board 480/5000 with difficulty 100.0
# Generated board 481/5000 with difficulty 100.0
# Generated board 482/5000 with difficulty 100.0
# Generated board 483/5000 with difficulty 100.0
# Generated board 484/5000 with difficulty 100.0
# Generated board 485/5000 with difficulty 100.0
# Generated board 486/5000 with difficulty 100.0
# Generated board 487/5000 with difficulty 100.0
# Generated board 488/5000 with difficulty 100.0
# Generated board 489/5000 with difficulty 100.0
# Generated board 490/5000 with difficulty 100.0
# Generated board 491/5000 with difficulty 100.0
# Generated board 492/5000 with difficulty 100.0
# Generated board 493/5000 with difficulty 100.0
# Generated board 494/5000 with difficulty 100.0
# Generated board 495/5000 with difficulty 100.0
# Generated board 496/5000 with difficulty 100.0
# Generated board 497/5000 with difficulty 100.0
# Generated board 498/5000 with difficulty 100.0
# Generated board 499/5000 with difficulty 100.0
# Generated board 500/5000 with difficulty 100.0
# Generated board 501/5000 with difficulty 100.0
# Generated board 502/5000 with difficulty 100.0
# Generated board 503/5000 with difficulty 100.0
# Generated board 504/5000 with difficulty 100.0
# Generated board 505/5000 with difficulty 100.0
# Generated board 506/5000 with difficulty 100.0
# Generated board 507/5000 with difficulty 100.0
# Generated board 508/5000 with difficulty 100.0
# Generated board 509/5000 with difficulty 100.0
# Generated board 510/5000 with difficulty 100.0
# Generated board 511/5000 with difficulty 100.0
# Generated board 512/5000 with difficulty 100.0
# Generated board 513/5000 with difficulty 100.0
# Generated board 514/5000 with difficulty 100.0
# Generated board 515/5000 with difficulty 100.0
# Generated board 516/5000 with difficulty 100.0
# Generated board 517/5000 with difficulty 100.0
# Generated board 518/5000 with difficulty 100.0
# Generated board 519/5000 with difficulty 100.0
# Generated board 520/5000 with difficulty 100.0
# Generated board 521/5000 with difficulty 100.0
# Generated board 522/5000 with difficulty 100.0
# Generated board 523/5000 with difficulty 100.0
# Generated board 524/5000 with difficulty 100.0
# Generated board 525/5000 with difficulty 100.0
# Generated board 526/5000 with difficulty 100.0
# Generated board 527/5000 with difficulty 100.0
# Generated board 528/5000 with difficulty 100.0
# Generated board 529/5000 with difficulty 100.0
# Generated board 530/5000 with difficulty 100.0
# Generated board 531/5000 with difficulty 100.0
# Generated board 532/5000 with difficulty 100.0
# Generated board 533/5000 with difficulty 100.0
# Generated board 534/5000 with difficulty 100.0
# Generated board 535/5000 with difficulty 100.0
# Generated board 536/5000 with difficulty 100.0
# Generated board 537/5000 with difficulty 100.0
# Generated board 538/5000 with difficulty 100.0
# Generated board 539/5000 with difficulty 100.0
# Generated board 540/5000 with difficulty 100.0
# Generated board 541/5000 with difficulty 100.0
# Generated board 542/5000 with difficulty 100.0
# Generated board 543/5000 with difficulty 100.0
# Generated board 544/5000 with difficulty 100.0
# Generated board 545/5000 with difficulty 100.0
# Generated board 546/5000 with difficulty 100.0
# Generated board 547/5000 with difficulty 100.0
# Generated board 548/5000 with difficulty 100.0
# Generated board 549/5000 with difficulty 100.0
# Generated board 550/5000 with difficulty 100.0
# Generated board 551/5000 with difficulty 100.0
# Generated board 552/5000 with difficulty 100.0
# Generated board 553/5000 with difficulty 100.0
# Generated board 554/5000 with difficulty 100.0
# Generated board 555/5000 with difficulty 100.0
# Generated board 556/5000 with difficulty 100.0
# Generated board 557/5000 with difficulty 100.0
# Generated board 558/5000 with difficulty 100.0
# Generated board 559/5000 with difficulty 100.0
# Generated board 560/5000 with difficulty 100.0
# Generated board 561/5000 with difficulty 100.0
# Generated board 562/5000 with difficulty 100.0
# Generated board 563/5000 with difficulty 100.0
# Generated board 564/5000 with difficulty 100.0
# Generated board 565/5000 with difficulty 100.0
# Generated board 566/5000 with difficulty 100.0
# Generated board 567/5000 with difficulty 100.0
# Generated board 568/5000 with difficulty 100.0
# Generated board 569/5000 with difficulty 100.0
# Generated board 570/5000 with difficulty 100.0
# Generated board 571/5000 with difficulty 100.0
# Generated board 572/5000 with difficulty 100.0
# Generated board 573/5000 with difficulty 100.0
# Generated board 574/5000 with difficulty 100.0
# Generated board 575/5000 with difficulty 100.0
# Generated board 576/5000 with difficulty 100.0
# Generated board 577/5000 with difficulty 100.0
# Generated board 578/5000 with difficulty 100.0
# Generated board 579/5000 with difficulty 100.0
# Generated board 580/5000 with difficulty 100.0
# Generated board 581/5000 with difficulty 100.0
# Generated board 582/5000 with difficulty 100.0
# Generated board 583/5000 with difficulty 100.0
# Generated board 584/5000 with difficulty 100.0
# Generated board 585/5000 with difficulty 100.0
# Generated board 586/5000 with difficulty 100.0
# Generated board 587/5000 with difficulty 100.0
# Generated board 588/5000 with difficulty 100.0
# Generated board 589/5000 with difficulty 100.0
# Generated board 590/5000 with difficulty 100.0
# Generated board 591/5000 with difficulty 100.0
# Generated board 592/5000 with difficulty 100.0
# Generated board 593/5000 with difficulty 100.0
# Generated board 594/5000 with difficulty 100.0
# Generated board 595/5000 with difficulty 100.0
# Generated board 596/5000 with difficulty 100.0
# Generated board 597/5000 with difficulty 100.0
# Generated board 598/5000 with difficulty 100.0
# Generated board 599/5000 with difficulty 100.0
# Generated board 600/5000 with difficulty 100.0
# Generated board 601/5000 with difficulty 100.0
# Generated board 602/5000 with difficulty 100.0
# Generated board 603/5000 with difficulty 100.0
# Generated board 604/5000 with difficulty 100.0
# Generated board 605/5000 with difficulty 100.0
# Generated board 606/5000 with difficulty 100.0
# Generated board 607/5000 with difficulty 100.0
# Generated board 608/5000 with difficulty 100.0
# Generated board 609/5000 with difficulty 100.0
# Generated board 610/5000 with difficulty 100.0
# Generated board 611/5000 with difficulty 100.0
# Generated board 612/5000 with difficulty 100.0
# Generated board 613/5000 with difficulty 100.0
# Generated board 614/5000 with difficulty 100.0
# Generated board 615/5000 with difficulty 100.0
# Generated board 616/5000 with difficulty 100.0
# Generated board 617/5000 with difficulty 100.0
# Generated board 618/5000 with difficulty 100.0
# Generated board 619/5000 with difficulty 100.0
# Generated board 620/5000 with difficulty 100.0
# Generated board 621/5000 with difficulty 100.0
# Generated board 622/5000 with difficulty 100.0
# Generated board 623/5000 with difficulty 100.0
# Generated board 624/5000 with difficulty 100.0
# Generated board 625/5000 with difficulty 100.0
# Generated board 626/5000 with difficulty 100.0
# Generated board 627/5000 with difficulty 100.0
# Generated board 628/5000 with difficulty 100.0
# Generated board 629/5000 with difficulty 100.0
# Generated board 630/5000 with difficulty 100.0
# Generated board 631/5000 with difficulty 100.0
# Generated board 632/5000 with difficulty 100.0
# Generated board 633/5000 with difficulty 100.0
# Generated board 634/5000 with difficulty 100.0
# Generated board 635/5000 with difficulty 100.0
# Generated board 636/5000 with difficulty 100.0
# Generated board 637/5000 with difficulty 100.0
# Generated board 638/5000 with difficulty 100.0
# Generated board 639/5000 with difficulty 100.0
# Generated board 640/5000 with difficulty 100.0
# Generated board 641/5000 with difficulty 100.0
# Generated board 642/5000 with difficulty 100.0
# Generated board 643/5000 with difficulty 100.0
# Generated board 644/5000 with difficulty 100.0
# Generated board 645/5000 with difficulty 100.0
# Generated board 646/5000 with difficulty 100.0
# Generated board 647/5000 with difficulty 100.0
# Generated board 648/5000 with difficulty 100.0
# Generated board 649/5000 with difficulty 100.0
# Generated board 650/5000 with difficulty 100.0
# Generated board 651/5000 with difficulty 100.0
# Generated board 652/5000 with difficulty 100.0
# Generated board 653/5000 with difficulty 100.0
# Generated board 654/5000 with difficulty 100.0
# Generated board 655/5000 with difficulty 100.0
# Generated board 656/5000 with difficulty 100.0
# Generated board 657/5000 with difficulty 100.0
# Generated board 658/5000 with difficulty 100.0
# Generated board 659/5000 with difficulty 100.0
# Generated board 660/5000 with difficulty 100.0
# Generated board 661/5000 with difficulty 100.0
# Generated board 662/5000 with difficulty 100.0
# Generated board 663/5000 with difficulty 100.0
# Generated board 664/5000 with difficulty 100.0
# Generated board 665/5000 with difficulty 100.0
# Generated board 666/5000 with difficulty 100.0
# Generated board 667/5000 with difficulty 100.0
# Generated board 668/5000 with difficulty 100.0
# Generated board 669/5000 with difficulty 100.0
# Generated board 670/5000 with difficulty 100.0
# Generated board 671/5000 with difficulty 100.0
# Generated board 672/5000 with difficulty 100.0
# Generated board 673/5000 with difficulty 100.0
# Generated board 674/5000 with difficulty 100.0
# Generated board 675/5000 with difficulty 100.0
# Generated board 676/5000 with difficulty 100.0
# Generated board 677/5000 with difficulty 100.0
# Generated board 678/5000 with difficulty 100.0
# Generated board 679/5000 with difficulty 100.0
# Generated board 680/5000 with difficulty 100.0
# Generated board 681/5000 with difficulty 100.0
# Generated board 682/5000 with difficulty 100.0
# Generated board 683/5000 with difficulty 100.0
# Generated board 684/5000 with difficulty 100.0
# Generated board 685/5000 with difficulty 100.0
# Generated board 686/5000 with difficulty 100.0
# Generated board 687/5000 with difficulty 100.0
# Generated board 688/5000 with difficulty 100.0
# Generated board 689/5000 with difficulty 100.0
# Generated board 690/5000 with difficulty 100.0
# Generated board 691/5000 with difficulty 100.0
# Generated board 692/5000 with difficulty 100.0
# Generated board 693/5000 with difficulty 100.0
# Generated board 694/5000 with difficulty 100.0
# Generated board 695/5000 with difficulty 100.0
# Generated board 696/5000 with difficulty 100.0
# Generated board 697/5000 with difficulty 100.0
# Generated board 698/5000 with difficulty 100.0
# Generated board 699/5000 with difficulty 100.0
# Generated board 700/5000 with difficulty 100.0
# Generated board 701/5000 with difficulty 100.0
# Generated board 702/5000 with difficulty 100.0
# Generated board 703/5000 with difficulty 100.0
# Generated board 704/5000 with difficulty 100.0
# Generated board 705/5000 with difficulty 100.0
# Generated board 706/5000 with difficulty 100.0
# Generated board 707/5000 with difficulty 100.0
# Generated board 708/5000 with difficulty 100.0
# Generated board 709/5000 with difficulty 100.0
# Generated board 710/5000 with difficulty 100.0
# Generated board 711/5000 with difficulty 100.0
# Generated board 712/5000 with difficulty 100.0
# Generated board 713/5000 with difficulty 100.0
# Generated board 714/5000 with difficulty 100.0
# Generated board 715/5000 with difficulty 100.0
# Generated board 716/5000 with difficulty 100.0
# Generated board 717/5000 with difficulty 100.0
# Generated board 718/5000 with difficulty 100.0
# Generated board 719/5000 with difficulty 100.0
# Generated board 720/5000 with difficulty 100.0
# Generated board 721/5000 with difficulty 100.0
# Generated board 722/5000 with difficulty 100.0
# Generated board 723/5000 with difficulty 100.0
# Generated board 724/5000 with difficulty 100.0
# Generated board 725/5000 with difficulty 100.0
# Generated board 726/5000 with difficulty 100.0
# Generated board 727/5000 with difficulty 100.0
# Generated board 728/5000 with difficulty 100.0
# Generated board 729/5000 with difficulty 100.0
# Generated board 730/5000 with difficulty 100.0
# Generated board 731/5000 with difficulty 100.0
# Generated board 732/5000 with difficulty 100.0
# Generated board 733/5000 with difficulty 100.0
# Generated board 734/5000 with difficulty 100.0
# Generated board 735/5000 with difficulty 100.0
# Generated board 736/5000 with difficulty 100.0
# Generated board 737/5000 with difficulty 100.0
# Generated board 738/5000 with difficulty 100.0
# Generated board 739/5000 with difficulty 100.0
# Generated board 740/5000 with difficulty 100.0
# Generated board 741/5000 with difficulty 100.0
# Generated board 742/5000 with difficulty 100.0
# Generated board 743/5000 with difficulty 100.0
# Generated board 744/5000 with difficulty 100.0
# Generated board 745/5000 with difficulty 100.0
# Generated board 746/5000 with difficulty 100.0
# Generated board 747/5000 with difficulty 100.0
# Generated board 748/5000 with difficulty 100.0
# Generated board 749/5000 with difficulty 100.0
# Generated board 750/5000 with difficulty 100.0
# Generated board 751/5000 with difficulty 100.0
# Generated board 752/5000 with difficulty 100.0
# Generated board 753/5000 with difficulty 100.0
# Generated board 754/5000 with difficulty 100.0
# Generated board 755/5000 with difficulty 100.0
# Generated board 756/5000 with difficulty 100.0
# Generated board 757/5000 with difficulty 100.0
# Generated board 758/5000 with difficulty 100.0
# Generated board 759/5000 with difficulty 100.0
# Generated board 760/5000 with difficulty 100.0
# Generated board 761/5000 with difficulty 100.0
# Generated board 762/5000 with difficulty 100.0
# Generated board 763/5000 with difficulty 100.0
# Generated board 764/5000 with difficulty 100.0
# Generated board 765/5000 with difficulty 100.0
# Generated board 766/5000 with difficulty 100.0
# Generated board 767/5000 with difficulty 100.0
# Generated board 768/5000 with difficulty 100.0
# Generated board 769/5000 with difficulty 100.0
# Generated board 770/5000 with difficulty 100.0
# Generated board 771/5000 with difficulty 100.0
# Generated board 772/5000 with difficulty 100.0
# Generated board 773/5000 with difficulty 100.0
# Generated board 774/5000 with difficulty 100.0
# Generated board 775/5000 with difficulty 100.0
# Generated board 776/5000 with difficulty 100.0
# Generated board 777/5000 with difficulty 100.0
# Generated board 778/5000 with difficulty 100.0
# Generated board 779/5000 with difficulty 100.0
# Generated board 780/5000 with difficulty 100.0
# Generated board 781/5000 with difficulty 100.0
# Generated board 782/5000 with difficulty 100.0
# Generated board 783/5000 with difficulty 100.0
# Generated board 784/5000 with difficulty 100.0
# Generated board 785/5000 with difficulty 100.0
# Generated board 786/5000 with difficulty 100.0
# Generated board 787/5000 with difficulty 100.0
# Generated board 788/5000 with difficulty 100.0
# Generated board 789/5000 with difficulty 100.0
# Generated board 790/5000 with difficulty 100.0
# Generated board 791/5000 with difficulty 100.0
# Generated board 792/5000 with difficulty 100.0
# Generated board 793/5000 with difficulty 100.0
# Generated board 794/5000 with difficulty 100.0
# Generated board 795/5000 with difficulty 100.0
# Generated board 796/5000 with difficulty 100.0
# Generated board 797/5000 with difficulty 100.0
# Generated board 798/5000 with difficulty 100.0
# Generated board 799/5000 with difficulty 100.0
# Generated board 800/5000 with difficulty 100.0
# Generated board 801/5000 with difficulty 100.0
# Generated board 802/5000 with difficulty 100.0
# Generated board 803/5000 with difficulty 100.0
# Generated board 804/5000 with difficulty 100.0
# Generated board 805/5000 with difficulty 100.0
# Generated board 806/5000 with difficulty 100.0
# Generated board 807/5000 with difficulty 100.0
# Generated board 808/5000 with difficulty 100.0
# Generated board 809/5000 with difficulty 100.0
# Generated board 810/5000 with difficulty 100.0
# Generated board 811/5000 with difficulty 100.0
# Generated board 812/5000 with difficulty 100.0
# Generated board 813/5000 with difficulty 100.0
# Generated board 814/5000 with difficulty 100.0
# Generated board 815/5000 with difficulty 100.0
# Generated board 816/5000 with difficulty 100.0
# Generated board 817/5000 with difficulty 100.0
# Generated board 818/5000 with difficulty 100.0
# Generated board 819/5000 with difficulty 100.0
# Generated board 820/5000 with difficulty 100.0
# Generated board 821/5000 with difficulty 100.0
# Generated board 822/5000 with difficulty 100.0
# Generated board 823/5000 with difficulty 100.0
# Generated board 824/5000 with difficulty 100.0
# Generated board 825/5000 with difficulty 100.0
# Generated board 826/5000 with difficulty 100.0
# Generated board 827/5000 with difficulty 100.0
# Generated board 828/5000 with difficulty 100.0
# Generated board 829/5000 with difficulty 100.0
# Generated board 830/5000 with difficulty 100.0
# Generated board 831/5000 with difficulty 100.0
# Generated board 832/5000 with difficulty 100.0
# Generated board 833/5000 with difficulty 100.0
# Generated board 834/5000 with difficulty 100.0
# Generated board 835/5000 with difficulty 100.0
# Generated board 836/5000 with difficulty 100.0
# Generated board 837/5000 with difficulty 100.0
# Generated board 838/5000 with difficulty 100.0
# Generated board 839/5000 with difficulty 100.0
# Generated board 840/5000 with difficulty 100.0
# Generated board 841/5000 with difficulty 100.0
# Generated board 842/5000 with difficulty 100.0
# Generated board 843/5000 with difficulty 100.0
# Generated board 844/5000 with difficulty 100.0
# Generated board 845/5000 with difficulty 100.0
# Generated board 846/5000 with difficulty 100.0
# Generated board 847/5000 with difficulty 100.0
# Generated board 848/5000 with difficulty 100.0
# Generated board 849/5000 with difficulty 100.0
# Generated board 850/5000 with difficulty 100.0
# Generated board 851/5000 with difficulty 100.0
# Generated board 852/5000 with difficulty 100.0
# Generated board 853/5000 with difficulty 100.0
# Generated board 854/5000 with difficulty 100.0
# Generated board 855/5000 with difficulty 100.0
# Generated board 856/5000 with difficulty 100.0
# Generated board 857/5000 with difficulty 100.0
# Generated board 858/5000 with difficulty 100.0
# Generated board 859/5000 with difficulty 100.0
# Generated board 860/5000 with difficulty 100.0
# Generated board 861/5000 with difficulty 100.0
# Generated board 862/5000 with difficulty 100.0
# Generated board 863/5000 with difficulty 100.0
# Generated board 864/5000 with difficulty 100.0
# Generated board 865/5000 with difficulty 100.0
# Generated board 866/5000 with difficulty 100.0
# Generated board 867/5000 with difficulty 100.0
# Generated board 868/5000 with difficulty 100.0
# Generated board 869/5000 with difficulty 100.0
# Generated board 870/5000 with difficulty 100.0
# Generated board 871/5000 with difficulty 100.0
# Generated board 872/5000 with difficulty 100.0
# Generated board 873/5000 with difficulty 100.0
# Generated board 874/5000 with difficulty 100.0
# Generated board 875/5000 with difficulty 100.0
# Generated board 876/5000 with difficulty 100.0
# Generated board 877/5000 with difficulty 100.0
# Generated board 878/5000 with difficulty 100.0
# Generated board 879/5000 with difficulty 100.0
# Generated board 880/5000 with difficulty 100.0
# Generated board 881/5000 with difficulty 100.0
# Generated board 882/5000 with difficulty 100.0
# Generated board 883/5000 with difficulty 100.0
# Generated board 884/5000 with difficulty 100.0
# Generated board 885/5000 with difficulty 100.0
# Generated board 886/5000 with difficulty 100.0
# Generated board 887/5000 with difficulty 100.0
# Generated board 888/5000 with difficulty 100.0
# Generated board 889/5000 with difficulty 100.0
# Generated board 890/5000 with difficulty 100.0
# Generated board 891/5000 with difficulty 100.0
# Generated board 892/5000 with difficulty 100.0
# Generated board 893/5000 with difficulty 100.0
# Generated board 894/5000 with difficulty 100.0
# Generated board 895/5000 with difficulty 100.0
# Generated board 896/5000 with difficulty 100.0
# Generated board 897/5000 with difficulty 100.0
# Generated board 898/5000 with difficulty 100.0
# Generated board 899/5000 with difficulty 100.0
# Generated board 900/5000 with difficulty 100.0
# Generated board 901/5000 with difficulty 100.0
# Generated board 902/5000 with difficulty 100.0
# Generated board 903/5000 with difficulty 100.0
# Generated board 904/5000 with difficulty 100.0
# Generated board 905/5000 with difficulty 100.0
# Generated board 906/5000 with difficulty 100.0
# Generated board 907/5000 with difficulty 100.0
# Generated board 908/5000 with difficulty 100.0
# Generated board 909/5000 with difficulty 100.0
# Generated board 910/5000 with difficulty 100.0
# Generated board 911/5000 with difficulty 100.0
# Generated board 912/5000 with difficulty 100.0
# Generated board 913/5000 with difficulty 100.0
# Generated board 914/5000 with difficulty 100.0
# Generated board 915/5000 with difficulty 100.0
# Generated board 916/5000 with difficulty 100.0
# Generated board 917/5000 with difficulty 100.0
# Generated board 918/5000 with difficulty 100.0
# Generated board 919/5000 with difficulty 100.0
# Generated board 920/5000 with difficulty 100.0
# Generated board 921/5000 with difficulty 100.0
# Generated board 922/5000 with difficulty 100.0
# Generated board 923/5000 with difficulty 100.0
# Generated board 924/5000 with difficulty 100.0
# Generated board 925/5000 with difficulty 100.0
# Generated board 926/5000 with difficulty 100.0
# Generated board 927/5000 with difficulty 100.0
# Generated board 928/5000 with difficulty 100.0
# Generated board 929/5000 with difficulty 100.0
# Generated board 930/5000 with difficulty 100.0
# Generated board 931/5000 with difficulty 100.0
# Generated board 932/5000 with difficulty 100.0
# Generated board 933/5000 with difficulty 100.0
# Generated board 934/5000 with difficulty 100.0
# Generated board 935/5000 with difficulty 100.0
# Generated board 936/5000 with difficulty 100.0
# Generated board 937/5000 with difficulty 100.0
# Generated board 938/5000 with difficulty 100.0
# Generated board 939/5000 with difficulty 100.0
# Generated board 940/5000 with difficulty 100.0
# Generated board 941/5000 with difficulty 100.0
# Generated board 942/5000 with difficulty 100.0
# Generated board 943/5000 with difficulty 100.0
# Generated board 944/5000 with difficulty 100.0
# Generated board 945/5000 with difficulty 100.0
# Generated board 946/5000 with difficulty 100.0
# Generated board 947/5000 with difficulty 100.0
# Generated board 948/5000 with difficulty 100.0
# Generated board 949/5000 with difficulty 100.0
# Generated board 950/5000 with difficulty 100.0
# Generated board 951/5000 with difficulty 100.0
# Generated board 952/5000 with difficulty 100.0
# Generated board 953/5000 with difficulty 100.0
# Generated board 954/5000 with difficulty 100.0
# Generated board 955/5000 with difficulty 100.0
# Generated board 956/5000 with difficulty 100.0
# Generated board 957/5000 with difficulty 100.0
# Generated board 958/5000 with difficulty 100.0
# Generated board 959/5000 with difficulty 100.0
# Generated board 960/5000 with difficulty 100.0
# Generated board 961/5000 with difficulty 100.0
# Generated board 962/5000 with difficulty 100.0
# Generated board 963/5000 with difficulty 100.0
# Generated board 964/5000 with difficulty 100.0
# Generated board 965/5000 with difficulty 100.0
# Generated board 966/5000 with difficulty 100.0
# Generated board 967/5000 with difficulty 100.0
# Generated board 968/5000 with difficulty 100.0
# Generated board 969/5000 with difficulty 100.0
# Generated board 970/5000 with difficulty 100.0
# Generated board 971/5000 with difficulty 100.0
# Generated board 972/5000 with difficulty 100.0
# Generated board 973/5000 with difficulty 100.0
# Generated board 974/5000 with difficulty 100.0
# Generated board 975/5000 with difficulty 100.0
# Generated board 976/5000 with difficulty 100.0
# Generated board 977/5000 with difficulty 100.0
# Generated board 978/5000 with difficulty 100.0
# Generated board 979/5000 with difficulty 100.0
# Generated board 980/5000 with difficulty 100.0
# Generated board 981/5000 with difficulty 100.0
# Generated board 982/5000 with difficulty 100.0
# Generated board 983/5000 with difficulty 100.0
# Generated board 984/5000 with difficulty 100.0
# Generated board 985/5000 with difficulty 100.0
# Generated board 986/5000 with difficulty 100.0
# Generated board 987/5000 with difficulty 100.0
# Generated board 988/5000 with difficulty 100.0
# Generated board 989/5000 with difficulty 100.0
# Generated board 990/5000 with difficulty 100.0
# Generated board 991/5000 with difficulty 100.0
# Generated board 992/5000 with difficulty 100.0
# Generated board 993/5000 with difficulty 100.0
# Generated board 994/5000 with difficulty 100.0
# Generated board 995/5000 with difficulty 100.0
# Generated board 996/5000 with difficulty 100.0
# Generated board 997/5000 with difficulty 100.0
# Generated board 998/5000 with difficulty 100.0
# Generated board 999/5000 with difficulty 100.0
# Generated board 1000/5000 with difficulty 100.0
# Generated board 1001/5000 with difficulty 100.0
# Generated board 1002/5000 with difficulty 100.0
# Generated board 1003/5000 with difficulty 100.0
# Generated board 1004/5000 with difficulty 100.0
# Generated board 1005/5000 with difficulty 100.0
# Generated board 1006/5000 with difficulty 100.0
# Generated board 1007/5000 with difficulty 100.0
# Generated board 1008/5000 with difficulty 100.0
# Generated board 1009/5000 with difficulty 100.0
# Generated board 1010/5000 with difficulty 100.0
# Generated board 1011/5000 with difficulty 100.0
# Generated board 1012/5000 with difficulty 100.0
# Generated board 1013/5000 with difficulty 100.0
# Generated board 1014/5000 with difficulty 100.0
# Generated board 1015/5000 with difficulty 100.0
# Generated board 1016/5000 with difficulty 100.0
# Generated board 1017/5000 with difficulty 100.0
# Generated board 1018/5000 with difficulty 100.0
# Generated board 1019/5000 with difficulty 100.0
# Generated board 1020/5000 with difficulty 100.0
# Generated board 1021/5000 with difficulty 100.0
# Generated board 1022/5000 with difficulty 100.0
# ...
# Generated board 4825/5000 with difficulty 100.0
# Generated board 4826/5000 with difficulty 100.0
# Generated board 4827/5000 with difficulty 100.0
# Generated board 4828/5000 with difficulty 100.0
# Generated board 4829/5000 with difficulty 100.0
# Generated board 4830/5000 with difficulty 100.0
# Generated board 4831/5000 with difficulty 100.0
# Generated board 4832/5000 with difficulty 100.0
# Generated board 4833/5000 with difficulty 100.0
# Generated board 4834/5000 with difficulty 100.0
# Generated board 4835/5000 with difficulty 100.0
# Generated board 4836/5000 with difficulty 100.0
# Generated board 4837/5000 with difficulty 100.0
# Generated board 4838/5000 with difficulty 100.0
# Generated board 4839/5000 with difficulty 100.0
# Generated board 4840/5000 with difficulty 100.0
# Generated board 4841/5000 with difficulty 100.0
# Generated board 4842/5000 with difficulty 100.0
# Generated board 4843/5000 with difficulty 100.0
# Generated board 4844/5000 with difficulty 100.0
# Generated board 4845/5000 with difficulty 100.0
# Generated board 4846/5000 with difficulty 100.0
# Generated board 4847/5000 with difficulty 100.0
# Generated board 4848/5000 with difficulty 100.0
# Generated board 4849/5000 with difficulty 100.0
# Generated board 4850/5000 with difficulty 100.0
# Generated board 4851/5000 with difficulty 100.0
# Generated board 4852/5000 with difficulty 100.0
# Generated board 4853/5000 with difficulty 100.0
# Generated board 4854/5000 with difficulty 100.0
# Generated board 4855/5000 with difficulty 100.0
# Generated board 4856/5000 with difficulty 100.0
# Generated board 4857/5000 with difficulty 100.0
# Generated board 4858/5000 with difficulty 100.0
# Generated board 4859/5000 with difficulty 100.0
# Generated board 4860/5000 with difficulty 100.0
# Generated board 4861/5000 with difficulty 100.0
# Generated board 4862/5000 with difficulty 100.0
# Generated board 4863/5000 with difficulty 100.0
# Generated board 4864/5000 with difficulty 100.0
# Generated board 4865/5000 with difficulty 100.0
# Generated board 4866/5000 with difficulty 100.0
# Generated board 4867/5000 with difficulty 100.0
# Generated board 4868/5000 with difficulty 100.0
# Generated board 4869/5000 with difficulty 100.0
# Generated board 4870/5000 with difficulty 100.0
# Generated board 4871/5000 with difficulty 100.0
# Generated board 4872/5000 with difficulty 100.0
# Generated board 4873/5000 with difficulty 100.0
# Generated board 4874/5000 with difficulty 100.0
# Generated board 4875/5000 with difficulty 100.0
# Generated board 4876/5000 with difficulty 100.0
# Generated board 4877/5000 with difficulty 100.0
# Generated board 4878/5000 with difficulty 100.0
# Generated board 4879/5000 with difficulty 100.0
# Generated board 4880/5000 with difficulty 100.0
# Generated board 4881/5000 with difficulty 100.0
# Generated board 4882/5000 with difficulty 100.0
# Generated board 4883/5000 with difficulty 100.0
# Generated board 4884/5000 with difficulty 100.0
# Generated board 4885/5000 with difficulty 100.0
# Generated board 4886/5000 with difficulty 100.0
# Generated board 4887/5000 with difficulty 100.0
# Generated board 4888/5000 with difficulty 100.0
# Generated board 4889/5000 with difficulty 100.0
# Generated board 4890/5000 with difficulty 100.0
# Generated board 4891/5000 with difficulty 100.0
# Generated board 4892/5000 with difficulty 100.0
# Generated board 4893/5000 with difficulty 100.0
# Generated board 4894/5000 with difficulty 100.0
# Generated board 4895/5000 with difficulty 100.0
# Generated board 4896/5000 with difficulty 100.0
# Generated board 4897/5000 with difficulty 100.0
# Generated board 4898/5000 with difficulty 100.0
# Generated board 4899/5000 with difficulty 100.0
# Generated board 4900/5000 with difficulty 100.0
# Generated board 4901/5000 with difficulty 100.0
# Generated board 4902/5000 with difficulty 100.0
# Generated board 4903/5000 with difficulty 100.0
# Generated board 4904/5000 with difficulty 100.0
# Generated board 4905/5000 with difficulty 100.0
# Generated board 4906/5000 with difficulty 100.0
# Generated board 4907/5000 with difficulty 100.0
# Generated board 4908/5000 with difficulty 100.0
# Generated board 4909/5000 with difficulty 100.0
# Generated board 4910/5000 with difficulty 100.0
# Generated board 4911/5000 with difficulty 100.0
# Generated board 4912/5000 with difficulty 100.0
# Generated board 4913/5000 with difficulty 100.0
# Generated board 4914/5000 with difficulty 100.0
# Generated board 4915/5000 with difficulty 100.0
# Generated board 4916/5000 with difficulty 100.0
# Generated board 4917/5000 with difficulty 100.0
# Generated board 4918/5000 with difficulty 100.0
# Generated board 4919/5000 with difficulty 100.0
# Generated board 4920/5000 with difficulty 100.0
# Generated board 4921/5000 with difficulty 100.0
# Generated board 4922/5000 with difficulty 100.0
# Generated board 4923/5000 with difficulty 100.0
# Generated board 4924/5000 with difficulty 100.0
# Generated board 4925/5000 with difficulty 100.0
# Generated board 4926/5000 with difficulty 100.0
# Generated board 4927/5000 with difficulty 100.0
# Generated board 4928/5000 with difficulty 100.0
# Generated board 4929/5000 with difficulty 100.0
# Generated board 4930/5000 with difficulty 100.0
# Generated board 4931/5000 with difficulty 100.0
# Generated board 4932/5000 with difficulty 100.0
# Generated board 4933/5000 with difficulty 100.0
# Generated board 4934/5000 with difficulty 100.0
# Generated board 4935/5000 with difficulty 100.0
# Generated board 4936/5000 with difficulty 100.0
# Generated board 4937/5000 with difficulty 100.0
# Generated board 4938/5000 with difficulty 100.0
# Generated board 4939/5000 with difficulty 100.0
# Generated board 4940/5000 with difficulty 100.0
# Generated board 4941/5000 with difficulty 100.0
# Generated board 4942/5000 with difficulty 100.0
# Generated board 4943/5000 with difficulty 100.0
# Generated board 4944/5000 with difficulty 100.0
# Generated board 4945/5000 with difficulty 100.0
# Generated board 4946/5000 with difficulty 100.0
# Generated board 4947/5000 with difficulty 100.0
# Generated board 4948/5000 with difficulty 100.0
# Generated board 4949/5000 with difficulty 100.0
# Generated board 4950/5000 with difficulty 100.0
# Generated board 4951/5000 with difficulty 100.0
# Generated board 4952/5000 with difficulty 100.0
# Generated board 4953/5000 with difficulty 100.0
# Generated board 4954/5000 with difficulty 100.0
# Generated board 4955/5000 with difficulty 100.0
# Generated board 4956/5000 with difficulty 100.0
# Generated board 4957/5000 with difficulty 100.0
# Generated board 4958/5000 with difficulty 100.0
# Generated board 4959/5000 with difficulty 100.0
# Generated board 4960/5000 with difficulty 100.0
# Generated board 4961/5000 with difficulty 100.0
# Generated board 4962/5000 with difficulty 100.0
# Generated board 4963/5000 with difficulty 100.0
# Generated board 4964/5000 with difficulty 100.0
# Generated board 4965/5000 with difficulty 100.0
# Generated board 4966/5000 with difficulty 100.0
# Generated board 4967/5000 with difficulty 100.0
# Generated board 4968/5000 with difficulty 100.0
# Generated board 4969/5000 with difficulty 100.0
# Generated board 4970/5000 with difficulty 100.0
# Generated board 4971/5000 with difficulty 100.0
# Generated board 4972/5000 with difficulty 100.0
# Generated board 4973/5000 with difficulty 100.0
# Generated board 4974/5000 with difficulty 100.0
# Generated board 4975/5000 with difficulty 100.0
# Generated board 4976/5000 with difficulty 100.0
# Generated board 4977/5000 with difficulty 100.0
# Generated board 4978/5000 with difficulty 100.0
# Generated board 4979/5000 with difficulty 100.0
# Generated board 4980/5000 with difficulty 100.0
# Generated board 4981/5000 with difficulty 100.0
# Generated board 4982/5000 with difficulty 100.0
# Generated board 4983/5000 with difficulty 100.0
# Generated board 4984/5000 with difficulty 100.0
# Generated board 4985/5000 with difficulty 100.0
# Generated board 4986/5000 with difficulty 100.0
# Generated board 4987/5000 with difficulty 100.0
# Generated board 4988/5000 with difficulty 100.0
# Generated board 4989/5000 with difficulty 100.0
# Generated board 4990/5000 with difficulty 100.0
# Generated board 4991/5000 with difficulty 100.0
# Generated board 4992/5000 with difficulty 100.0
# Generated board 4993/5000 with difficulty 100.0
# Generated board 4994/5000 with difficulty 100.0
# Generated board 4995/5000 with difficulty 100.0
# Generated board 4996/5000 with difficulty 100.0
# Generated board 4997/5000 with difficulty 100.0
# Generated board 4998/5000 with difficulty 100.0
# Generated board 4999/5000 with difficulty 100.0
# Generated board 5000/5000 with difficulty 100.0
# Generated board 1/5000 with difficulty 100.0
# Generated board 2/5000 with difficulty 100.0
# Generated board 3/5000 with difficulty 100.0
# Generated board 4/5000 with difficulty 100.0
# Generated board 5/5000 with difficulty 100.0
# Generated board 6/5000 with difficulty 100.0
# Generated board 7/5000 with difficulty 100.0
# Generated board 8/5000 with difficulty 100.0
# Generated board 9/5000 with difficulty 100.0
# Generated board 10/5000 with difficulty 100.0
# Generated board 11/5000 with difficulty 100.0
# Generated board 12/5000 with difficulty 100.0
# Generated board 13/5000 with difficulty 100.0
# Generated board 14/5000 with difficulty 100.0
# Generated board 15/5000 with difficulty 100.0
# Generated board 16/5000 with difficulty 100.0
# Generated board 17/5000 with difficulty 100.0
# Generated board 18/5000 with difficulty 100.0
# Generated board 19/5000 with difficulty 100.0
# Generated board 20/5000 with difficulty 100.0
# Generated board 21/5000 with difficulty 100.0
# Generated board 22/5000 with difficulty 100.0
# Generated board 23/5000 with difficulty 100.0
# Generated board 24/5000 with difficulty 100.0
# Generated board 25/5000 with difficulty 100.0
# Generated board 26/5000 with difficulty 100.0
# Generated board 27/5000 with difficulty 100.0
# Generated board 28/5000 with difficulty 100.0
# Generated board 29/5000 with difficulty 100.0
# Generated board 30/5000 with difficulty 100.0
# Generated board 31/5000 with difficulty 100.0
# Generated board 32/5000 with difficulty 100.0
# Generated board 33/5000 with difficulty 100.0
# Generated board 34/5000 with difficulty 100.0
# Generated board 35/5000 with difficulty 100.0
# Generated board 36/5000 with difficulty 100.0
# Generated board 37/5000 with difficulty 100.0
# Generated board 38/5000 with difficulty 100.0
# Generated board 39/5000 with difficulty 100.0
# Generated board 40/5000 with difficulty 100.0
# Generated board 41/5000 with difficulty 100.0
# Generated board 42/5000 with difficulty 100.0
# Generated board 43/5000 with difficulty 100.0
# Generated board 44/5000 with difficulty 100.0
# Generated board 45/5000 with difficulty 100.0
# Generated board 46/5000 with difficulty 100.0
# Generated board 47/5000 with difficulty 100.0
# Generated board 48/5000 with difficulty 100.0
# Generated board 49/5000 with difficulty 100.0
# Generated board 50/5000 with difficulty 100.0
# Generated board 51/5000 with difficulty 100.0
# Generated board 52/5000 with difficulty 100.0
# Generated board 53/5000 with difficulty 100.0
# Generated board 54/5000 with difficulty 100.0
# Generated board 55/5000 with difficulty 100.0
# Generated board 56/5000 with difficulty 100.0
# Generated board 57/5000 with difficulty 100.0
# Generated board 58/5000 with difficulty 100.0
# Generated board 59/5000 with difficulty 100.0
# Generated board 60/5000 with difficulty 100.0
# Generated board 61/5000 with difficulty 100.0
# Generated board 62/5000 with difficulty 100.0
# Generated board 63/5000 with difficulty 100.0
# Generated board 64/5000 with difficulty 100.0
# Generated board 65/5000 with difficulty 100.0
# Generated board 66/5000 with difficulty 100.0
# Generated board 67/5000 with difficulty 100.0
# Generated board 68/5000 with difficulty 100.0
# Generated board 69/5000 with difficulty 100.0
# Generated board 70/5000 with difficulty 100.0
# Generated board 71/5000 with difficulty 100.0
# Generated board 72/5000 with difficulty 100.0
# Generated board 73/5000 with difficulty 100.0
# Generated board 74/5000 with difficulty 100.0
# Generated board 75/5000 with difficulty 100.0
# Generated board 76/5000 with difficulty 100.0
# Generated board 77/5000 with difficulty 100.0
# Generated board 78/5000 with difficulty 100.0
# Generated board 79/5000 with difficulty 100.0
# Generated board 80/5000 with difficulty 100.0
# Generated board 81/5000 with difficulty 100.0
# Generated board 82/5000 with difficulty 100.0
# Generated board 83/5000 with difficulty 100.0
# Generated board 84/5000 with difficulty 100.0
# Generated board 85/5000 with difficulty 100.0
# Generated board 86/5000 with difficulty 100.0
# Generated board 87/5000 with difficulty 100.0
# Generated board 88/5000 with difficulty 100.0
# Generated board 89/5000 with difficulty 100.0
# Generated board 90/5000 with difficulty 100.0
# Generated board 91/5000 with difficulty 100.0
# Generated board 92/5000 with difficulty 100.0
# Generated board 93/5000 with difficulty 100.0
# Generated board 94/5000 with difficulty 100.0
# Generated board 95/5000 with difficulty 100.0
# Generated board 96/5000 with difficulty 100.0
# Generated board 97/5000 with difficulty 100.0
# Generated board 98/5000 with difficulty 100.0
# Generated board 99/5000 with difficulty 100.0
# Generated board 100/5000 with difficulty 100.0
# Generated board 101/5000 with difficulty 100.0
# Generated board 102/5000 with difficulty 100.0
# Generated board 103/5000 with difficulty 100.0
# Generated board 104/5000 with difficulty 100.0
# Generated board 105/5000 with difficulty 100.0
# Generated board 106/5000 with difficulty 100.0
# Generated board 107/5000 with difficulty 100.0
# Generated board 108/5000 with difficulty 100.0
# Generated board 109/5000 with difficulty 100.0
# Generated board 110/5000 with difficulty 100.0
# Generated board 111/5000 with difficulty 100.0
# Generated board 112/5000 with difficulty 100.0
# Generated board 113/5000 with difficulty 100.0
# Generated board 114/5000 with difficulty 100.0
# Generated board 115/5000 with difficulty 100.0
# Generated board 116/5000 with difficulty 100.0
# Generated board 117/5000 with difficulty 100.0
# Generated board 118/5000 with difficulty 100.0
# Generated board 119/5000 with difficulty 100.0
# Generated board 120/5000 with difficulty 100.0
# Generated board 121/5000 with difficulty 100.0
# Generated board 122/5000 with difficulty 100.0
# Generated board 123/5000 with difficulty 100.0
# Generated board 124/5000 with difficulty 100.0
# Generated board 125/5000 with difficulty 100.0
# Generated board 126/5000 with difficulty 100.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 24
#      22 print(f"[{ts}] Starting")
#      23 for diff, (eaters, rows, cols, num_select, white_pct, min_food, minimum_qualified_colors) in DIFFICULTY.items():
# ---> 24     new_boards = gen_boards(num_select, 5000, rows, cols, eaters, min_food, "hard")
#      25     ts = time.time()
#      26     for board in new_boards:
#
# Cell In[1], line 572, in gen_boards(num_select, total_gen, rows, cols, eaters, min_food, difficulty_range)
#     569 if difficulty_targets:
#     570     target = random.randint(difficulty_targets[0], difficulty_targets[1])
# --> 572 difficulty = g.gen_puzzle(eaters, min_food, target)
#     574 empty_count = g.count_empty()
#     575 if empty_count == 0:
#     576     # All spaces filled, consider it a valid board
#
# Cell In[1], line 320, in Grid.gen_puzzle(self, eaters, min_food, target_difficulty)
#     317     if not moved_any: break
#     319 # Fill remaining spaces strategically to create challenging paths
# --> 320 self._strategic_fill(eater_pos)
#     322 # Calculate board difficulty
#     323 difficulty = self.analyze_board_complexity()
#
# Cell In[1], line 401, in Grid._strategic_fill(self, eater_pos)
#     399     if strategic_pos:
#     400         x, y = strategic_pos
# --> 401         self.place(Food(color), x, y)
#     402         filled += 1
#     404 # Fill remaining spaces with random food
#
# Cell In[1], line 19, in Food.__init__(self, color, is_last)
#      18 class Food(Entity):
# ---> 19     def __init__(self, color, is_last=False):
#      20         super().__init__(color)
#      21         self.is_last = is_last
#
# KeyboardInterrupt:
